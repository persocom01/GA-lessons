# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Web Scraping: Solutions
#
# _Author: Dave Yerrington (SF)_
#
# ---

# %% [markdown]
# ## Before Class
#
# #### Install Selenium
#
# Selenium is a headless browser. It allows us to render JavaScript just as a human-navigated browser would.
#
# To install Selenium, use one of the following:
# - **Anaconda:** `conda install -c conda-forge selenium`
# - **pip:** `pip install selenium`
#
#
# #### Install GeckoDriver
#
# You will also need GeckoDriver (this assumes you are using Homebrew for Mac):
#
# - ```brew install geckodriver```
#
# #### Install Firefox
#
# Additionally, you will need to have downloaded the [Firefox browser](https://www.mozilla.org/en-US/firefox/new/?utm_source=google&utm_medium=cpc&utm_campaign=Firefox-Brand-US-GGL-Exact&utm_term=firefox&utm_content=A144_A203_A006336&gclid=Cj0KEQjwnPLKBRC-j7nt1b7OlZwBEiQAv8lMLJUyReT6cPzSYdmEA6uD3YDoieuuuusddgAU7XH6smEaAoje8P8HAQ&gclsrc=aw.ds) for the application in this lesson.

# %% [markdown]
# ## Learning Objectives
# - Revisit how to locate elements on a webpage
# - Aquire unstructure data from the internet using Beautiful soup.
# - Discuss limitations associated with simple requests and urllib libraries
# - Introduce Selenium as a solution, and implement a scraper using selenium

# %% [markdown]
# ## Lesson Guide
#
# - [Introduction](#intro)
# - [Building a web scraper](#building-scraper)
# - [Retrieving data from the HTML page](#retrieving-data)
#     - [Retrieving the restaurant names](#retrieving-names)
#     - [Challenge: Retrieving the restaurant locations](#retrieving-locations)
#     - [Retrieving the restaurant prices](#retrieving-prices)
#     - [Retrieving the restaurant number of bookings](#retrieving-bookings)
#
#
# - [Introducting Selenium](#selenium)
#     - [Running JavaScript before scraping](#selenium-js)
#     - [Using regex to only get digits](#selenium-regex)
#     - [Challenge: Use Pandas to create a DataFrame of bookings](#challenge-pandas)
#     - [Auto-typing using Selenium](#selenium-typing)
#
#
# - [Summary](#summary)

# %% [markdown]
# <a id="intro"></a>
# ## Introduction
#
# In this codealong lesson, we'll build a web scraper using urllib and BeautifulSoup. We will also explore how to use a headless browser called Selenium.
#
# We'll begin by scraping OpenTable's DC listings. We're interested in knowing the restaurant's **name, location, price, and how many people booked it today.**
#
# OpenTable provides all of this information on this given page: http://www.opentable.com/washington-dc-restaurant-listings
#
# Let's inspect the elements of this page to assure we can find each of the bits of information in which we're interested.
#
# ---

# %% [markdown]
# <a id="building-scraper"></a>
# ## Building a web scraper
#
# Now, let's build a web scraper for OpenTable using urllib and Beautiful Soup:

# %%
# import our necessary first packages
from bs4 import BeautifulSoup
import requests

# %%
# set the url we want to visit
url = "http://www.opentable.com/washington-dc-restaurant-listings"

# visit that url, and grab the html of said page
html = requests.get(url)

# %% [markdown]
# At this point, what is in html?

# %%
# .text returns the request content in Unicode
html.text[:500]
# Out:
# '           <!DOCTYPE html><html lang="en"><head><meta charset="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=9; IE=8; IE=7; IE=EDGE"/> <title>Restaurant Reservation Availability</title>    <meta  name="robots" content="noindex" > </meta><link  rel="canonical" href="https://www.opentable.com/washington-dc-restaurant-listings" > </link>      <link rel="shortcut icon" href="//components.otstatic.com/components/favicon/1.0.5/favicon/favicon.ico" type="image/x-icon"/><link rel="icon" href="/'

# %% [markdown]
# We will need to convert this html objct into a soup object so we can parse it using python and BS4

# %%
# convert this into a soup object

# %% [markdown]
# <a id="retrieving-data"></a>
# ### Retrieving data from the HTML page

# %% [markdown]
# Let's first find each restaurant name listed on the page we've loaded. How do we find the page location of the restaurant? (Hint: We need to know where in the **HTML** the restaurant element is housed.) In order to find the HTML that renders the restaurant location, we can use Google Chrome's Inspect tool:
#
# > http://www.opentable.com/washington-dc-restaurant-listings
#
# > 1. Visit the URL above.
#
# > 2. Right-click on an element you are interested in, then choose Inspect (in Chrome).
#
# > 3. This will open the Developer Tools and show the HTML used to render the selected page element.
#
# > Throughout this lesson, we will use this method to find tags associated with elements of the page we want to scrape.
#
# See if you can find the restaurant name on the page. Keep in mind there are many restaurants loaded on the page.

# %%
# print the restaurant names
soup.find_all(name='span', attrs={'class':'rest-row-name-text'})
# Out:
# [<span class="rest-row-name-text">Thereses</span>,
#  <span class="rest-row-name-text">Zechariahs</span>,
#  <span class="rest-row-name-text">Faustos</span>,
#  <span class="rest-row-name-text">Ryleigh Cummings</span>,
#  <span class="rest-row-name-text">Aut Gutmann</span>,
#  <span class="rest-row-name-text">Kiara Padberg</span>,
#  <span class="rest-row-name-text">341 Gleason</span>,
#  <span class="rest-row-name-text">Carter Flats</span>,
#  <span class="rest-row-name-text">Lila Wunsch</span>,
#  <span class="rest-row-name-text">Cartwright Spring</span>,
#  <span class="rest-row-name-text">Ut Johnston</span>,
#  <span class="rest-row-name-text">Cupiditate Roob</span>,
#  <span class="rest-row-name-text">16 Weissnat</span>,
#  <span class="rest-row-name-text">Merediths</span>,
#  <span class="rest-row-name-text">Lehner</span>,
#  <span class="rest-row-name-text">Reprehenderit</span>,
#  <span class="rest-row-name-text">Prairie</span>,
#  <span class="rest-row-name-text">Marielas</span>,
#  <span class="rest-row-name-text">Lon Ledner</span>,
#  <span class="rest-row-name-text">Oberbrunner Mountain</span>,
#  <span class="rest-row-name-text">Saepe</span>,
#  <span class="rest-row-name-text">Corwin</span>,
#  <span class="rest-row-name-text">Porro</span>,
#  <span class="rest-row-name-text">1497 Trantow</span>,
#  <span class="rest-row-name-text">678 Heidenreich</span>,
#  <span class="rest-row-name-text">Ville</span>,
#  <span class="rest-row-name-text">503 Schoen</span>,
#  <span class="rest-row-name-text">1112 Kris</span>,
#  <span class="rest-row-name-text">93 Bradtke</span>,
#  <span class="rest-row-name-text">Loop</span>,
#  <span class="rest-row-name-text">Agloe Bar &amp; Grill</span>,
#  <span class="rest-row-name-text">Vista</span>,
#  <span class="rest-row-name-text">Corrupti</span>,
#  <span class="rest-row-name-text">Iure Macejkovic</span>,
#  <span class="rest-row-name-text">Autem Ward</span>,
#  <span class="rest-row-name-text">Nesciunt</span>,
#  <span class="rest-row-name-text">Carrie Rapids</span>,
#  <span class="rest-row-name-text">Gonzalo Schimmel</span>,
#  <span class="rest-row-name-text">598 Braun</span>,
#  <span class="rest-row-name-text">Dolore</span>,
#  <span class="rest-row-name-text">Candelarios</span>,
#  <span class="rest-row-name-text">Dolore Will</span>,
#  <span class="rest-row-name-text">Dandre Bode</span>,
#  <span class="rest-row-name-text">Iure Manor</span>,
#  <span class="rest-row-name-text">Geo Parkway</span>,
#  <span class="rest-row-name-text">113 Harber</span>,
#  <span class="rest-row-name-text">Joaquins</span>,
#  <span class="rest-row-name-text">Sporer</span>,
#  <span class="rest-row-name-text">Rowe</span>,
#  <span class="rest-row-name-text">Velit Crest</span>,
#  <span class="rest-row-name-text">Sit Ford</span>,
#  <span class="rest-row-name-text">Christops</span>,
#  <span class="rest-row-name-text">Lakin</span>,
#  <span class="rest-row-name-text">Macejkovic</span>,
#  <span class="rest-row-name-text">Dolor Waters</span>,
#  <span class="rest-row-name-text">Veum Forks</span>,
#  <span class="rest-row-name-text">Et Spring</span>,
#  <span class="rest-row-name-text">Farrell</span>,
#  <span class="rest-row-name-text">Aut</span>,
#  <span class="rest-row-name-text">Clemenss</span>,
#  <span class="rest-row-name-text">Path</span>,
#  <span class="rest-row-name-text">Aut Knoll</span>,
#  <span class="rest-row-name-text">Kozey</span>,
#  <span class="rest-row-name-text">Voluptas Light</span>,
#  <span class="rest-row-name-text">Titos</span>,
#  <span class="rest-row-name-text">Harvey</span>,
#  <span class="rest-row-name-text">Coy Bins</span>,
#  <span class="rest-row-name-text">Quaerat Ratke</span>,
#  <span class="rest-row-name-text">Unde Rapid</span>,
#  <span class="rest-row-name-text">Nyasias</span>,
#  <span class="rest-row-name-text">Ways</span>,
#  <span class="rest-row-name-text">Sanford</span>,
#  <span class="rest-row-name-text">Sadies</span>,
#  <span class="rest-row-name-text">Vans</span>,
#  <span class="rest-row-name-text">Emily Locks</span>,
#  <span class="rest-row-name-text">Causeway</span>,
#  <span class="rest-row-name-text">Omnis</span>,
#  <span class="rest-row-name-text">Pariatur Oberbrunner</span>,
#  <span class="rest-row-name-text">Veritatis Harris</span>,
#  <span class="rest-row-name-text">Amet Run</span>,
#  <span class="rest-row-name-text">Tenetur Howe</span>,
#  <span class="rest-row-name-text">Eugenia Gerlach</span>,
#  <span class="rest-row-name-text">Hannahs</span>,
#  <span class="rest-row-name-text">Dolorem</span>,
#  <span class="rest-row-name-text">Marcelluss</span>,
#  <span class="rest-row-name-text">Fahey</span>,
#  <span class="rest-row-name-text">Officia</span>,
#  <span class="rest-row-name-text">Quia</span>,
#  <span class="rest-row-name-text">840 Halvorson</span>,
#  <span class="rest-row-name-text">Reiciendis Herzog</span>,
#  <span class="rest-row-name-text">Provident Burgs</span>,
#  <span class="rest-row-name-text">Impedit Grant</span>,
#  <span class="rest-row-name-text">Kirsten Homenick</span>,
#  <span class="rest-row-name-text">Vel</span>,
#  <span class="rest-row-name-text">Plaza</span>,
#  <span class="rest-row-name-text">Quas</span>,
#  <span class="rest-row-name-text">Beatty</span>,
#  <span class="rest-row-name-text">Similique Light</span>,
#  <span class="rest-row-name-text">Quia Shore</span>,
#  <span class="rest-row-name-text">Mills</span>]

# %% [markdown]
# It is important to always keep in mind the data types that were returned. Note this is a `list`, and we know that immediately by observing the outer square brackets and commas separating each tag.
#
# Next, note the elements of the list are `Tag` objects, not strings. (If they were strings, they would be surrounded by quotes.) The Beautiful Soup authors chose to display a `Tag` object visually as a text representation of the tag and its contents. However, being an object, it has many methods that we can call on it. For example, next we will use the `encode_contents()` method to return the tag's contents encoded as a Python string.
#
# <a id="retrieving-names"></a>
# #### Retrieving the restaurant names
#
# Now that we found a list of tags containing the restaurant names, let's think how we can loop through them all one-by-one. In the following cell, we'll print out the name (and **only** the clean name, not the rest of the html) of each restaurant.

# %%
# for each element you find, print out the restaurant name
for entry in soup.find_all(name='span', attrs={'class':'rest-row-name-text'}):
    print(entry.text)
# Out:
# Thereses
# Zechariahs
# Faustos
# Ryleigh Cummings
# Aut Gutmann
# Kiara Padberg
# 341 Gleason
# Carter Flats
# Lila Wunsch
# Cartwright Spring
# Ut Johnston
# Cupiditate Roob
# 16 Weissnat
# Merediths
# Lehner
# Reprehenderit
# Prairie
# Marielas
# Lon Ledner
# Oberbrunner Mountain
# Saepe
# Corwin
# Porro
# 1497 Trantow
# 678 Heidenreich
# Ville
# 503 Schoen
# 1112 Kris
# 93 Bradtke
# Loop
# Agloe Bar & Grill
# Vista
# Corrupti
# Iure Macejkovic
# Autem Ward
# Nesciunt
# Carrie Rapids
# Gonzalo Schimmel
# 598 Braun
# Dolore
# Candelarios
# Dolore Will
# Dandre Bode
# Iure Manor
# Geo Parkway
# 113 Harber
# Joaquins
# Sporer
# Rowe
# Velit Crest
# Sit Ford
# Christops
# Lakin
# Macejkovic
# Dolor Waters
# Veum Forks
# Et Spring
# Farrell
# Aut
# Clemenss
# Path
# Aut Knoll
# Kozey
# Voluptas Light
# Titos
# Harvey
# Coy Bins
# Quaerat Ratke
# Unde Rapid
# Nyasias
# Ways
# Sanford
# Sadies
# Vans
# Emily Locks
# Causeway
# Omnis
# Pariatur Oberbrunner
# Veritatis Harris
# Amet Run
# Tenetur Howe
# Eugenia Gerlach
# Hannahs
# Dolorem
# Marcelluss
# Fahey
# Officia
# Quia
# 840 Halvorson
# Reiciendis Herzog
# Provident Burgs
# Impedit Grant
# Kirsten Homenick
# Vel
# Plaza
# Quas
# Beatty
# Similique Light
# Quia Shore
# Mills

# %% [markdown]
# Great!
#
# <a id="retrieving-locations"></a>
# #### Challenge: Retrieving the restaurant locations
#
# Can you repeat that process for finding the location? For example, barmini by Jose Andres is in the location listed as "Penn Quarter" in our search results.

# %%
# first, see if you can identify the location for all elements -- print it out
soup.find_all('span', {'class':'rest-row-meta--location rest-row-meta-text'})
# Out:
# [<span class="rest-row-meta--location rest-row-meta-text">North Anabellemouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">North Priscilla</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Consuelo</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Jody</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Clair</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Jaydeshire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Edenhaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">North Larryview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Antonietta</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Peytonmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Odie</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Abbottchester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Maryjaneland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Sonnyton</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Adolphton</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Alexanderberg</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Nicholausport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Lou</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Edythfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Conorton</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Rainafort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Kleinborough</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Alyceberg</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Zemlakburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Tad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Remingtonburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Albaville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Madonnaport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Fidelland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Jackbury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Gerholdview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">North Vergie</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Billyton</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Alfred</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Derekhaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Traceside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Staceyport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Sophiafurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Verlieburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Kellenfort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Dariusland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Sydni</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Israel</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Noemi</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Delaneyfort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Cassinport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Shadmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Sydnietown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Harveyside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Karolann</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Dickishire</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lebsackview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Emilia</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Stewart</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Kareemborough</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Legrosfurt</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Marianne</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Myron</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Wymanside</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Joeyberg</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">North Betty</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Millsburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Tylerstad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Lura</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Gabrielle</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Zemlakchester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Filomenachester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lowellfort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Adalinebury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Marquiseland</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Aureliebury</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">North Davonteport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Kaycee</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">North Trinity</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Hester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Pearl</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Orpha</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Frederik</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Tristonmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Port Geovanny</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Langville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">South Kian</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Koeppstad</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Kristinachester</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Ceciliaburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Douglasburgh</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Nathenhaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Stantonfort</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Willardborough</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Lake Mandyville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Arlene</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Tristintown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">New Revaborough</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Willmstown</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Johnsmouth</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Durwardville</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">Chynaport</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">East Arvelview</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Joaniehaven</span>,
#  <span class="rest-row-meta--location rest-row-meta-text">West Tiana</span>]

# %%
# now print out EACH location for the restaurants
for entry in soup.find_all('span', {'class':'rest-row-meta--location rest-row-meta-text'}):
    print(entry.text)
# Out:
# North Anabellemouth
# North Priscilla
# New Consuelo
# Port Jody
# South Clair
# Port Jaydeshire
# Edenhaven
# North Larryview
# Port Antonietta
# Peytonmouth
# Port Odie
# Abbottchester
# Maryjaneland
# New Sonnyton
# Adolphton
# Alexanderberg
# West Nicholausport
# East Lou
# West Edythfurt
# Conorton
# Rainafort
# Kleinborough
# Alyceberg
# Zemlakburgh
# West Tad
# East Remingtonburgh
# Albaville
# Madonnaport
# Fidelland
# Jackbury
# Gerholdview
# North Vergie
# Lake Billyton
# East Alfred
# Derekhaven
# Traceside
# Staceyport
# Sophiafurt
# Verlieburgh
# Port Kellenfort
# Port Dariusland
# New Sydni
# West Israel
# Lake Noemi
# South Delaneyfort
# Cassinport
# Shadmouth
# Port Sydnietown
# Harveyside
# South Karolann
# Dickishire
# Lebsackview
# East Emilia
# West Stewart
# East Kareemborough
# Legrosfurt
# West Marianne
# Lake Myron
# Wymanside
# Joeyberg
# North Betty
# Millsburgh
# Tylerstad
# South Lura
# South Gabrielle
# Zemlakchester
# Filomenachester
# Lowellfort
# Adalinebury
# East Marquiseland
# Aureliebury
# North Davonteport
# South Kaycee
# North Trinity
# Port Hester
# New Pearl
# East Orpha
# Port Frederik
# Tristonmouth
# Port Geovanny
# Langville
# South Kian
# Koeppstad
# Kristinachester
# Lake Ceciliaburgh
# Douglasburgh
# Nathenhaven
# Stantonfort
# Willardborough
# Lake Mandyville
# New Arlene
# Tristintown
# New Revaborough
# Willmstown
# Johnsmouth
# Durwardville
# Chynaport
# East Arvelview
# West Joaniehaven
# West Tiana

# %% [markdown]
# <a id="retrieving-prices"></a>
# #### Retrieving the restaurant prices

# %% [markdown]
# Ok, we've figured out the restaurant name and location. Now we need to grab the price (number of dollar signs on a scale of one to four) for each restaurant. We'll follow the same process.

# %%
# print out all prices
soup.find_all('div', {'class':'rest-row-pricing'})
# Out:
# [<div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    </i> <span class="pricing--not-the-price">  $        </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $    $    $  </i> <span class="pricing--not-the-price"> </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>,
#  <div class="rest-row-pricing"> <i class="pricing--the-price">  $    $      </i> <span class="pricing--not-the-price">  $    $      </span></div>]

# %%
# print out EACH number of dollar signs per restaurant
# this one is trickier to eliminate the html. Hint: try a nested find
for entry in soup.find_all('div', {'class':'rest-row-pricing'}):
    print(entry.find('i').text)
# Out:
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $    $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $
#   $    $
#   $    $    $
#   $    $    $    $
#   $    $    $
#   $    $    $
#   $    $    $    $
#   $    $    $    $
#   $    $
#   $    $

# %% [markdown]
# That looks great, but what if I wanted just the number of dollar signs per restaurant? Can you figure out a way to simply print out the number of dollar signs per restaurant listed?

# %%
# print the number of dollars signs per restaurant
for entry in soup.find_all('div', {'class':'rest-row-pricing'}):
    price = entry.find('i').text
    print(price.count('$'))
# Out:
# 4
# 4
# 3
# 3
# 2
# 4
# 4
# 2
# 3
# 4
# 3
# 2
# 4
# 2
# 2
# 4
# 3
# 3
# 4
# 2
# 3
# 3
# 4
# 3
# 4
# 3
# 3
# 4
# 2
# 4
# 4
# 3
# 4
# 2
# 2
# 2
# 3
# 4
# 4
# 3
# 2
# 3
# 4
# 4
# 2
# 2
# 2
# 4
# 3
# 2
# 2
# 2
# 3
# 4
# 3
# 2
# 3
# 3
# 3
# 3
# 4
# 3
# 3
# 4
# 2
# 2
# 4
# 2
# 3
# 2
# 2
# 3
# 3
# 4
# 3
# 4
# 4
# 2
# 2
# 2
# 4
# 2
# 4
# 2
# 3
# 4
# 4
# 3
# 4
# 3
# 2
# 2
# 3
# 4
# 3
# 3
# 4
# 4
# 2
# 2

# %% [markdown]
# Phew, nice work.
#
# <a id="retrieving-bookings"></a>
# #### Retrieving the restaurant number of bookings
#
# One more, right? We only need to find the number times a restaurant was booked. In the next cell, print out all objects that contain the number of times the restaurant was booked.

# %%
# print out all objects that contain the number of times the restaurant was booked
soup.find_all('div', {'class':'booking'})
# Out:
# []

# %% [markdown]
# That's weird -- an empty set. Did we find the wrong element? What's going on here? Discuss.
#
# How can we debug this? Any ideas?

# %%
# let's first try printing out all 'div' objects
#  NOTE: This is a too many objects to store in this notebook!
#        So, uncomment the code below to run it.

# for entry in soup.find_all('div'):
#     print entry

# %% [markdown]
# I still don't see it. Let's search our entire soup object:

# %%
# print out soup, do command+f for "booked ". 
#   Uncomment the below to run.

# soup

# %% [markdown]
# What do you notice? Why is this happening?

# %%
html =  requests.get('https://santabarbara.craigslist.org/d/apts-housing-for-rent/search/apa')
soup_cl = BeautifulSoup(html.text, 'html.parser')

# %%
results = soup_cl.find_all('p', attrs={'class': 'result-info'})
listings = []
for result in results:
    result_dict = {}
    result_dict['title'] = result.find('a').text
    result_dict['price'] = result.find('span', attrs={'class': 'result-price'}).text
    listings.append(result_dict)

listings
# Out:
# [{'title': 'Exclusive Hope Ranch House, 3 bedroom+Bonus Rm, 4 Bath',
#   'price': '$13500'},
#  {'title': 'Beautiful Garden Setting', 'price': '$2024'},
#  {'title': 'Montecito Enchanted Hedgerow Studio Cottage', 'price': '$2900'},
#  {'title': 'Spanish Style', 'price': '$1825'},
#  {'title': 'Downtown Carpinteria Beach Bungalow, 2 + Bonus Rm, 2 Bath',
#   'price': '$3995'},
#  {'title': 'Lovely Montecito Home, 4 Bedroom + Office, 5 Bath',
#   'price': '$8700'},
#  {'title': 'GREAT AMENITIES!HUGE WALK IN CLOSET!SHORT TERM LEASE',
#   'price': '$2495'},
#  {'title': 'Reserve Large 1BR/1BA apt for as little as $600 down this weeknd only!',
#   'price': '$1842'},
#  {'title': 'Newly Renovated With Amazing Natural Light. Furnished Unit',
#   'price': '$2495'},
#  {'title': 'room for rent $900', 'price': '$900'},
#  {'title': 'Bright 1 Bedroom Apartment', 'price': '$1095'},
#  {'title': 'MOVE IN NOW !! FURNISHED ONE BEDROOM! WIFI/ CABLE INCLUDED',
#   'price': '$2495'},
#  {'title': 'Live Your Best Life With Us!', 'price': '$3100'},
#  {'title': '50-203 Hop on over to Willow Springs |The Towbes Group',
#   'price': '$2600'},
#  {'title': 'DEPOSIT SPECIAL!! Reserve your 1BR/1BA apt $300 off!',
#   'price': '$1737'},
#  {'title': '☀ The sun is shining on your NEW HOME!! Tour today! |The Towbes Group',
#   'price': '$2185'},
#  {'title': '2/1 Home on Sunny Oak Park', 'price': '$2250'},
#  {'title': 'Place your hold today for Summer/Fall! 2 bed 1.5 bath town house',
#   'price': '$2727'},
#  {'title': 'Horses Welcome!!! 5 Bedroom house on 30 acres overlooking Santa Ynez',
#   'price': '$3995'},
#  {'title': '6656 Sueno Road', 'price': '$4395'},
#  {'title': '6582 Sabado Tarde Apartments', 'price': '$1620'},
#  {'title': 'Bright 1 Bedroom in West Beach', 'price': '$2795'},
#  {'title': '1Bdrm + Office ~ City, ocean view apt attached to gated pool home',
#   'price': '$2550'},
#  {'title': 'Downtown Santa Barbara, Oak hardwood floors', 'price': '$2595'},
#  {'title': 'Furnished Cottage for Rent for May and June', 'price': '$2500'},
#  {'title': '3 Bed 2 bath Luxurious apt! Washer/Dryer included with NO UTILITIES!',
#   'price': '$4250'},
#  {'title': 'Available Now! 2 Bed, 2 bath condo for rent', 'price': '$2195'},
#  {'title': 'Luxury living at the Marc!', 'price': '$3495'},
#  {'title': 'NEWLY RENOVATED 2 BEDROOM 1.5 BATHROOM TOWNHOUSE!!',
#   'price': '$2895'},
#  {'title': 'BEAUTIFUL 2 BEDROOM 1.5 BATHROOM NOW RENTING', 'price': '$2895'},
#  {'title': 'Large 1 Bedroom Apartment', 'price': '$1700'},
#  {'title': 'Gorgeous Just Remodeled 2 Bedroom!  2 Full Baths Upstairs Corner Unit!',
#   'price': '$2895'},
#  {'title': 'Remodeled Kitchen and Bathroom!!!  Summerland Views, Views, Views!',
#   'price': '$1825'},
#  {'title': '1 Bed - 1 Bath, Spacious Walk-In Closet, Private Balcony/Patio',
#   'price': '$2505'},
#  {'title': 'Spacious 2bed/2bath Apartment Available ($700 Off First Months Rent)',
#   'price': '$3495'},
#  {'title': 'Summerland Views, Views, Views!  Remodeled Kitchen and Bathroom!!!',
#   'price': '$1750'},
#  {'title': 'Gorgeous Remodeled 1 Bedroom Duplex! Brand New Kitchen & New Bathroom!',
#   'price': '$1895'},
#  {'title': 'Just One Block from State!  Beautiful UPSTAIRS Studio!!!',
#   'price': '$1350'},
#  {'title': 'Studio + Bd Rm + Pool, Private Porch & Sm Priv Yard',
#   'price': '$1595'},
#  {'title': 'Newer flooring & paint, upstairs, parking (jp-16)',
#   'price': '$1720'},
#  {'title': 'Upstairs with balcony, parking, close to UCSB (g6e-8)',
#   'price': '$2290'},
#  {'title': 'End unit, downtown, parking, new floors (w5i-e)',
#   'price': '$1695'},
#  {'title': 'Between Mesa & downtown, remodeled, balcony (d7c-8)',
#   'price': '$1695'},
#  {'title': 'Downtown studio, no smoking, spacious (ds-15)', 'price': '$1695'},
#  {'title': 'Downtown, spacious, shared back yard, W/T/G included (r1b-27)',
#   'price': '$1725'},
#  {'title': 'Near Alameda Park, downtown, new vinyl, fresh paint (h4s-3)',
#   'price': '$1795'},
#  {'title': 'New flooring, fresh paint, spacious, close to UCSB (ge-10)',
#   'price': '$1475'},
#  {'title': '2 Bedroom Apartment Near Downtown', 'price': '$2175'},
#  {'title': 'Very large, upstairs with balcony, new carpet, no cosigners (r6e-4)',
#   'price': '$2275'},
#  {'title': 'Bamboo floors, near Cottage Hospital, modern interior (j0d-7)',
#   'price': '$1795'},
#  {'title': 'Uptown near La Cumbre Plaza, end unit, pool (cb-11)',
#   'price': '$1525'},
#  {'title': '2 Bedroom Apartment Near Downtown', 'price': '$2125'},
#  {'title': 'Close to UCSB, Costco, new blinds, fresh paint (c3e-10)',
#   'price': '$1695'},
#  {'title': '1 Bedroom in the Heart of Downtown', 'price': '$1750'},
#  {'title': 'Rarely available! Spacious, wood flrs, views, W/T/G/E included (cw0t)',
#   'price': '$2695'},
#  {'title': 'Open floor plan, large, patio, off street parking (g5p-a)',
#   'price': '$1625'},
#  {'title': '1 Bedroom Apartment Near Paseo Nuevo', 'price': '$1795'},
#  {'title': 'More Mesa Shores Home', 'price': '$5400'},
#  {'title': 'Large 3 Bedroom, 3 Bathroom', 'price': '$3000'},
#  {'title': 'Beautiful Summerland House', 'price': '$3325'},
#  {'title': 'Cute Cottage Bungalow in Downtown', 'price': '$1950'},
#  {'title': 'Large Downstairs Apartment in 55+ Living Community',
#   'price': '$2695'},
#  {'title': 'Spacious Townhose Near Downtown', 'price': '$2500'},
#  {'title': 'Charming 3 Bedroom Home', 'price': '$2500'},
#  {'title': "1 Bedroom at Laguna Apartments ($500 off 1st Month's Rent!)",
#   'price': '$1895'},
#  {'title': 'Single Family 3 Bedroom Home', 'price': '$3750'},
#  {'title': 'Assigned Covered Carport Parking, Built-in WIFI Sound System, Range',
#   'price': '$3100'},
#  {'title': 'Built-in WIFI Sound System, Oil Rubbed Bronze Fixtures, Balcony',
#   'price': '$3075'},
#  {'title': '$3000 2/2 craftsman with lots of charm', 'price': '$3000'},
#  {'title': 'Contemporary Unfurnished, Quiet Studio', 'price': '$1690'},
#  {'title': 'Newer 2 Bed, 2.5 Bath Condo', 'price': '$2500'},
#  {'title': '$2700 Horse Facility', 'price': '$2700'},
#  {'title': 'Heart of downtown, luxury furnished, short/long term, garage + parking',
#   'price': '$4450'},
#  {'title': 'New Luxury Apartments Now Leasing!', 'price': '$1595'},
#  {'title': '2 Bedroom/ 1 Bathroom', 'price': '$2200'},
#  {'title': '2 Bed - 2 Bath, Granite Countertops, Private Balcony/Patio',
#   'price': '$3156'},
#  {'title': 'PRIVATE RANCH-Country Living In Santa Barbara', 'price': '$5995'},
#  {'title': 'Upstairs condo 4 bed/2 bath w/d hook up, garage, pool',
#   'price': '$3375'},
#  {'title': '3925 Harrold Ave,Avail. 13/1 - Op.Hse Sat/Sun 4/13&4/14 from 11-1pm',
#   'price': '$850'},
#  {'title': '3925 Harrold Ave,Avail. 13/1 - Op.Hse Sat/Sun 4/13&4/14 from 11-1pm',
#   'price': '$850'},
#  {'title': '3925 Harrold Ave,Avail. 13/1 - Op.Hse Sat/Sun 4/13&4/14 from 11-1pm',
#   'price': '$850'},
#  {'title': '2 Bed - 2 Bath, Visit Your New Home Today!', 'price': '$3136'},
#  {'title': '2 Bed - 2 Bath, Private Balcony/Patio, Pool, Spa and 24 Hr Gym!',
#   'price': '$3181'},
#  {'title': 'DOG FRIENDLY small Studio w/ Large private patio & yard-All Util Incl',
#   'price': '$1600'},
#  {'title': '2 Bed - 2 Bath, Spacious Walk-In Closet, Oversized Patios',
#   'price': '$3131'},
#  {'title': 'Spacious and Sunny home, 4BR/3BA', 'price': '$6500'},
#  {'title': '2 Bed - 2 Bath, Welcome Home! Visit Us Today! Available Now!',
#   'price': '$3181'},
#  {'title': 'Spacious and private house suitable for up to 14 people!',
#   'price': '$8900'},
#  {'title': 'MONTECITO HISTORIC STUNNING 2 BR & 1 BA HOME WITH GARAGE AND YARD',
#   'price': '$2750'},
#  {'title': 'NEAR LOWER RIVIERA-CHARMING 1 BR DUPLEX ON QUIET LANE',
#   'price': '$1475'},
#  {'title': 'NEAR TURNPIKE-LUXURY 2 BR & 1 1/2 BATH TOWNHOME-QUARTZ GOURMET KITCHEN',
#   'price': '$2550'},
#  {'title': '2/2 Craftsman', 'price': '$3000'},
#  {'title': '2 Bed - 2 Bath, Entry Foyer, Spacious Walk-In Closet',
#   'price': '$3156'},
#  {'title': '2 Bedroom Home on a Quiet Street on the Westside',
#   'price': '$3150'},
#  {'title': 'Private furnished room on the Mesa', 'price': '$1000'},
#  {'title': 'Individual leasing by the bed, Courtesy officer, Pet friendly',
#   'price': '$1225'},
#  {'title': '2 Bed - 2 Bath, Private Balcony/Patio, Granite Countertops, & Garage!',
#   'price': '$3136'},
#  {'title': 'Cap cod style setting', 'price': '$2250'},
#  {'title': 'Ellwood beach dr.apartments', 'price': '$1550'},
#  {'title': 'Lovely 2Bedroom Townhouse', 'price': '$2850'},
#  {'title': "3 bedroom 1.5 bath Won't last", 'price': '$1925'},
#  {'title': '2-Story, 4 Bedroom House For Rent', 'price': '$2500'},
#  {'title': 'Spiral stairs in some apartments, Surfboard lockers, Close to SBCC',
#   'price': '$1225'},
#  {'title': 'unique one bedroom apartment for rent', 'price': '$1800'},
#  {'title': 'Looking To Move Fast? Check This 2x2 Out!', 'price': '$3100'},
#  {'title': '3bed 1.5 bath, Perfect for you and friends! Unit wont last long!',
#   'price': '$3195'},
#  {'title': 'Apartment Near SB Bowl (3rd Floor)', 'price': '$1795'},
#  {'title': 'Apartment Near SB Bowl (2nd Floor)', 'price': '$1795'},
#  {'title': '2 Bed - 2 Bath, Available now! $500 off your move in cost, join Today!',
#   'price': '$3136'},
#  {'title': '1BR/1BA Third Floor Unit w/ Pool', 'price': '$1795'},
#  {'title': 'Apartment Near SB Bowl (2nd Floor)', 'price': '$1850'},
#  {'title': '1 and 2 bedrooms Available in May!', 'price': '$1595'},
#  {'title': '1BR/1BA Second Floor Unit w/ Courtyard', 'price': '$1795'},
#  {'title': '1BR/1BA Second Floor Unit w/ Pool', 'price': '$1850'},
#  {'title': 'Spacious 1BR/1BA in excellent downtown location',
#   'price': '$1795'},
#  {'title': 'Upstairs 1BR/1BA at Villa Flores', 'price': '$1795'},
#  {'title': '1BR/1BA Available at Villa Flores', 'price': '$1850'},
#  {'title': 'Paint your own accent wall at the Marc!', 'price': '$3495'},
#  {'title': 'Dual pane windows, Simple online bill pay, Surfboard lockers',
#   'price': '$1250'},
#  {'title': 'Cute, cozy and private 2 Bedroom/1ba Duplex', 'price': '$3100'}]

# %% [markdown]
# <a id="selenium"></a>
# ## Introducing Selenium
#
# Selenium is a headless browser. It allows us to render JavaScript just as a human-navigated browser would.
#
# To install Selenium, use one of the following:
# - **Anaconda:** `conda install -c conda-forge selenium`
# - **pip:** `pip install selenium`
#
# You will also need GeckoDriver (this assumes you are using Homebrew for Mac):
#
# - ```brew install geckodriver```
#
# Additionally, you will need to have downloaded the [Firefox browser](https://www.mozilla.org/en-US/firefox/new/?utm_source=google&utm_medium=cpc&utm_campaign=Firefox-Brand-US-GGL-Exact&utm_term=firefox&utm_content=A144_A203_A006336&gclid=Cj0KEQjwnPLKBRC-j7nt1b7OlZwBEiQAv8lMLJUyReT6cPzSYdmEA6uD3YDoieuuuusddgAU7XH6smEaAoje8P8HAQ&gclsrc=aw.ds) for the application in this lesson.

# %%
# import
from selenium import webdriver

# %% [markdown]
# Selenium requires us to determine a default browser to run. I'm going to opt for Firefox, but Chromium is also a very common choice. http://selenium-python.readthedocs.io/faq.html

# %%
# STOP
# what is going to happen when I run the next cell?

# %%
# create a driver called Firefox
driver = webdriver.Firefox()

# %% [markdown]
# Pretty crazy, right? Let's close that driver.

# %%
# close it
driver.close()

# %%
# let's boot it up, and visit a URL of our choice
driver = webdriver.Firefox()
driver.get("http://www.python.org")

# %% [markdown]
# Awesome. Now we're getting somewhere: programmatically controlling our browser like a human.

# %% [markdown]
# Let's return to our problem at hand. We need to visit the OpenTable listing for DC. Once there, we need to get the html to load. In the next cell, prove you can programmatically visit the page.

# %%
# visit our OpenTable page
driver = webdriver.Firefox()
driver.get("http://www.opentable.com/washington-dc-restaurant-listings")

# always good to check we've got the page we think we do
assert "OpenTable" in driver.title

# %%
driver.title
# Out:
# u'Washington, D.C. Area Restaurants List | OpenTable'

# %%
driver.close()

# %% [markdown]
# <a id="selenium-js"></a>
# ### Running JavaScript before scraping
#
# Now, to resolve our JavaScript problem, there's a few things we can do. What I'll do in this case is request that the page load, wait one second, and then I'm going to grab the source html from the page. Because the page should believe I'm visiting from a live connection on a browser client, the JavaScript should render to be a part of the page source. I can then grab the page source.

# %%
# import sleep
from time import sleep

# %%
# visit our relevant page
driver = webdriver.Firefox()
driver.get("http://www.opentable.com/washington-dc-restaurant-listings")

# wait one second
sleep(1)

#grab the page source
html = driver.page_source

# %% [markdown]
# **Pop Quiz:** What do we need to do with this HTML?

# %%
# BeautifulSoup it!
html = BeautifulSoup(html, "lxml")

# %% [markdown]
# Now, let's return to our earlier problem: How do we locate bookings on the page?

# %%
# print out the number bookings for all restaurants
html.find_all('div', {'class':'booking'})
# Out:
# [<div class="booking"><span class="tadpole"></span>Booked 423 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 259 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 208 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 247 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 101 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 73 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 80 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 112 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 42 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 59 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 67 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 55 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 62 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 47 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 60 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 47 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 42 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 32 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 34 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 46 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 21 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 16 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 54 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 1 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 25 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 17 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 5 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 30 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 99 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 2 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 4 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 25 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>,
#  <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>]

# %%
# now print out each booking for the listings using a loop
for entry in html.find_all('div', {'class':'booking'}):
    print(entry)
# Out:
# <div class="booking"><span class="tadpole"></span>Booked 423 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 259 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 208 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 247 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 101 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 73 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 80 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 112 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 42 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 59 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 67 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 55 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 62 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 47 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 60 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 47 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 42 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 32 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 34 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 46 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 21 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 16 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 54 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 1 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 25 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 17 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 5 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 30 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 99 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 2 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 4 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 25 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>

# %% [markdown]
# Let's grab just the text of each of these entries.

# %%
# do the same as above, but grabbing only the text content
for entry in html.find_all('div', {'class':'booking'}):
    print(entry.text)
# Out:
# Booked 423 times today
# Booked 259 times today
# Booked 208 times today
# Booked 247 times today
# Booked 101 times today
# Booked 73 times today
# Booked 80 times today
# Booked 112 times today
# Booked 43 times today
# Booked 31 times today
# Booked 49 times today
# Booked 43 times today
# Booked 42 times today
# Booked 59 times today
# Booked 26 times today
# Booked 67 times today
# Booked 52 times today
# Booked 55 times today
# Booked 62 times today
# Booked 47 times today
# Booked 60 times today
# Booked 50 times today
# Booked 47 times today
# Booked 42 times today
# Booked 32 times today
# Booked 34 times today
# Booked 46 times today
# Booked 52 times today
# Booked 11 times today
# Booked 12 times today
# Booked 20 times today
# Booked 15 times today
# Booked 26 times today
# Booked 19 times today
# Booked 28 times today
# Booked 40 times today
# Booked 11 times today
# Booked 49 times today
# Booked 21 times today
# Booked 26 times today
# Booked 27 times today
# Booked 13 times today
# Booked 28 times today
# Booked 40 times today
# Booked 38 times today
# Booked 27 times today
# Booked 14 times today
# Booked 16 times today
# Booked 18 times today
# Booked 15 times today
# Booked 52 times today
# Booked 49 times today
# Booked 54 times today
# Booked 13 times today
# Booked 26 times today
# Booked 1 times today
# Booked 12 times today
# Booked 35 times today
# Booked 19 times today
# Booked 24 times today
# Booked 43 times today
# Booked 13 times today
# Booked 14 times today
# Booked 23 times today
# Booked 50 times today
# Booked 19 times today
# Booked 20 times today
# Booked 18 times today
# Booked 18 times today
# Booked 25 times today
# Booked 9 times today
# Booked 27 times today
# Booked 17 times today
# Booked 20 times today
# Booked 7 times today
# Booked 9 times today
# Booked 52 times today
# Booked 23 times today
# Booked 5 times today
# Booked 23 times today
# Booked 30 times today
# Booked 19 times today
# Booked 14 times today
# Booked 99 times today
# Booked 19 times today
# Booked 12 times today
# Booked 14 times today
# Booked 2 times today
# Booked 8 times today
# Booked 18 times today
# Booked 4 times today
# Booked 7 times today
# Booked 6 times today
# Booked 11 times today
# Booked 8 times today
# Booked 25 times today
# Booked 7 times today
# Booked 6 times today

# %%
driver.close()

# %% [markdown]
# We've succeeded!
#
# <a id="selenium-regex"></a>
# ### Using regex to only get digits
#
# But we can clean this up a little bit. We're going to use regular expressions (regex) to grab only the digits that are available in each of the text.
#
# The best way to get good at regex is to, well, just keep trying and testing: http://pythex.org/

# %%
# import regex
import re

# %% [markdown]
# Given we haven't covered regex, I'll show you how to use the search function to match any given digit.

# %%
# for each entry, grab the text
for booking in html.find_all('div', {'class':'booking'}):
    # match all digits
    match = re.search(r'\d+', booking.text)
    
    if match:
        # print if found
        print(match.group())
    else:
        # otherwise pass
        pass
# Out:
# 423
# 259
# 208
# 247
# 101
# 73
# 80
# 112
# 43
# 31
# 49
# 43
# 42
# 59
# 26
# 67
# 52
# 55
# 62
# 47
# 60
# 50
# 47
# 42
# 32
# 34
# 46
# 52
# 11
# 12
# 20
# 15
# 26
# 19
# 28
# 40
# 11
# 49
# 21
# 26
# 27
# 13
# 28
# 40
# 38
# 27
# 14
# 16
# 18
# 15
# 52
# 49
# 54
# 13
# 26
# 1
# 12
# 35
# 19
# 24
# 43
# 13
# 14
# 23
# 50
# 19
# 20
# 18
# 18
# 25
# 9
# 27
# 17
# 20
# 7
# 9
# 52
# 23
# 5
# 23
# 30
# 19
# 14
# 99
# 19
# 12
# 14
# 2
# 8
# 18
# 4
# 7
# 6
# 11
# 8
# 25
# 7
# 6

# %% [markdown]
# Before we demonstrate all the other amazing things about headless browsers, let's finish up collecting the data we want from this current example. Do you suppose the html parsing we wrote above will still work on the page source we've grabbed from our headless browser?

# %% [markdown]
# To be most efficient, we want to only do a single loop for each entry on the page. That means we want to find what element all of other other elements (name, location, price, bookings) is housed within. Where on the page is each entry located?

# %%
# print out all entries
#   NOTE: Has many entries. Uncomment the below code to run it!

# soup.find_all('div', {'class':'result content-section-list-row cf with-times'})

# %% [markdown]
# Look over the page. Does every single entry have each element we're seeking?
# > I did this previously. I know for a fact that not every element has a number of recent bookings. That's probably exactly why OpenTable houses this in JavaScript: they want to continously update the number of bookings with the most relevant number of values.

# %%
# We want to only retrieve the text of the bookings.
# But what would happen if we just naively print the text of each node?

for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
    print(entry.find('div', {'class':'booking'}))   # try adding .text
# Out:
# None
# None
# <div class="booking"><span class="tadpole"></span>Booked 423 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 259 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 208 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 247 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 101 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 73 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 80 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 112 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 31 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 42 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 59 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 67 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 55 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 62 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 47 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 60 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 47 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 42 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 32 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 34 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 46 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 21 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 28 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 40 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 38 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 16 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 15 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 49 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 54 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 26 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 1 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 35 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 24 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 43 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 13 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 50 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 25 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 27 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 17 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 20 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 9 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 52 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 5 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 23 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 30 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 99 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 19 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 12 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 14 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 2 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 18 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 4 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 11 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 8 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 25 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 7 times today</div>
# <div class="booking"><span class="tadpole"></span>Booked 6 times today</div>

# %%
# if we find the element we want, we print it. Otherwise, we print 'ZERO'
for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
        divs = entry.find('div', {'class':'booking'})
        
        if divs:
            print(divs.text)
        else:
            print('ZERO')
# Out:
# ZERO
# ZERO
# Booked 423 times today
# Booked 259 times today
# Booked 208 times today
# Booked 247 times today
# Booked 101 times today
# Booked 73 times today
# Booked 80 times today
# Booked 112 times today
# Booked 43 times today
# Booked 31 times today
# Booked 49 times today
# Booked 43 times today
# Booked 42 times today
# Booked 59 times today
# Booked 26 times today
# Booked 67 times today
# Booked 52 times today
# Booked 55 times today
# Booked 62 times today
# Booked 47 times today
# Booked 60 times today
# Booked 50 times today
# Booked 47 times today
# Booked 42 times today
# Booked 32 times today
# Booked 34 times today
# Booked 46 times today
# Booked 52 times today
# Booked 11 times today
# Booked 12 times today
# Booked 20 times today
# Booked 15 times today
# Booked 26 times today
# Booked 19 times today
# Booked 28 times today
# Booked 40 times today
# Booked 11 times today
# Booked 49 times today
# Booked 21 times today
# Booked 26 times today
# Booked 27 times today
# Booked 13 times today
# Booked 28 times today
# Booked 40 times today
# Booked 38 times today
# Booked 27 times today
# Booked 14 times today
# Booked 16 times today
# Booked 18 times today
# Booked 15 times today
# Booked 52 times today
# Booked 49 times today
# Booked 54 times today
# Booked 13 times today
# Booked 26 times today
# Booked 1 times today
# Booked 12 times today
# Booked 35 times today
# Booked 19 times today
# Booked 24 times today
# Booked 43 times today
# Booked 13 times today
# Booked 14 times today
# Booked 23 times today
# Booked 50 times today
# Booked 19 times today
# Booked 20 times today
# Booked 18 times today
# Booked 18 times today
# Booked 25 times today
# Booked 9 times today
# Booked 27 times today
# Booked 17 times today
# Booked 20 times today
# Booked 7 times today
# Booked 9 times today
# Booked 52 times today
# Booked 23 times today
# Booked 5 times today
# Booked 23 times today
# Booked 30 times today
# Booked 19 times today
# Booked 14 times today
# Booked 99 times today
# Booked 19 times today
# Booked 12 times today
# Booked 14 times today
# Booked 2 times today
# Booked 8 times today
# Booked 18 times today
# Booked 4 times today
# Booked 7 times today
# Booked 6 times today
# Booked 11 times today
# Booked 8 times today
# Booked 25 times today
# Booked 7 times today
# Booked 6 times today

# %% [markdown]
# What do you notice takes the place when booking is not found?
#
# We could use exception handling (`try`/`except` blocks) to resolve this. However, exceptions should only be used to handle rare or unexpected errors -- never for normal program flow.
#
# In this case, we expect that some entries will be zero. So, we can just use an `if` statement that tests whether there are any `divs` present; if not, display `'ZERO'`. Here's a demo:

# %%
# if we find the element we want, we print it. Otherwise, we print 'ZERO'
for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
    booking_tag = entry.find('div', {'class':'booking'})
    
    if booking_tag:
        print(booking_tag.text)
    else:
        print('ZERO')
# Out:
# ZERO
# ZERO
# Booked 423 times today
# Booked 259 times today
# Booked 208 times today
# Booked 247 times today
# Booked 101 times today
# Booked 73 times today
# Booked 80 times today
# Booked 112 times today
# Booked 43 times today
# Booked 31 times today
# Booked 49 times today
# Booked 43 times today
# Booked 42 times today
# Booked 59 times today
# Booked 26 times today
# Booked 67 times today
# Booked 52 times today
# Booked 55 times today
# Booked 62 times today
# Booked 47 times today
# Booked 60 times today
# Booked 50 times today
# Booked 47 times today
# Booked 42 times today
# Booked 32 times today
# Booked 34 times today
# Booked 46 times today
# Booked 52 times today
# Booked 11 times today
# Booked 12 times today
# Booked 20 times today
# Booked 15 times today
# Booked 26 times today
# Booked 19 times today
# Booked 28 times today
# Booked 40 times today
# Booked 11 times today
# Booked 49 times today
# Booked 21 times today
# Booked 26 times today
# Booked 27 times today
# Booked 13 times today
# Booked 28 times today
# Booked 40 times today
# Booked 38 times today
# Booked 27 times today
# Booked 14 times today
# Booked 16 times today
# Booked 18 times today
# Booked 15 times today
# Booked 52 times today
# Booked 49 times today
# Booked 54 times today
# Booked 13 times today
# Booked 26 times today
# Booked 1 times today
# Booked 12 times today
# Booked 35 times today
# Booked 19 times today
# Booked 24 times today
# Booked 43 times today
# Booked 13 times today
# Booked 14 times today
# Booked 23 times today
# Booked 50 times today
# Booked 19 times today
# Booked 20 times today
# Booked 18 times today
# Booked 18 times today
# Booked 25 times today
# Booked 9 times today
# Booked 27 times today
# Booked 17 times today
# Booked 20 times today
# Booked 7 times today
# Booked 9 times today
# Booked 52 times today
# Booked 23 times today
# Booked 5 times today
# Booked 23 times today
# Booked 30 times today
# Booked 19 times today
# Booked 14 times today
# Booked 99 times today
# Booked 19 times today
# Booked 12 times today
# Booked 14 times today
# Booked 2 times today
# Booked 8 times today
# Booked 18 times today
# Booked 4 times today
# Booked 7 times today
# Booked 6 times today
# Booked 11 times today
# Booked 8 times today
# Booked 25 times today
# Booked 7 times today
# Booked 6 times today

# %% [markdown]
# After previously completing this, we observed that all other elements WILL be returned. This means we do not have to always handle these cases.
#
# <a id="challenge-pandas"></a>
# ### Challenge: Use Pandas to create a DataFrame of bookings
#
# However, the onus is on you to now put all the pieces together.
#
# Loop through each entry. For each entry, grab the relevant information we want (name, location, price, bookings). Produce a dataframe with the columns "name","location","price","bookings" that contains the 100 entries we would like.

# %%
import pandas as pd

# %%
# I'm going to create my empty df first
dc_eats = pd.DataFrame(columns=["name","location","price","bookings"])

# %%
for entry in html.find_all('div', {'class':'result content-section-list-row cf with-times'}):
    # grab the name
    name = entry.find('span', {'class':'rest-row-name-text'}).text
    
    # grab the location 
    location = entry.find('span', {'class':'rest-row-meta--location rest-row-meta-text'}).text
    
    # grab the price
    price = entry.find('div', {'class':'rest-row-pricing'}).find('i').text.count('$')
    
    # try to find the number of bookings
    bookings = 'NA'
    booking_tag = entry.find('div', {'class':'booking'})
    if booking_tag:
        match = re.search('\d+', booking_tag.text)
        
        if match:
            bookings = match.group()
    
    dc_eats.loc[len(dc_eats)]=[name, location, price, bookings]

# %%
# check out our work
dc_eats.head()
# Out:
#                           name      location price bookings
# 0  Joe's Place Pizza and Pasta     Arlington     2       NA
# 1        Ruffino's - Arlington     Arlington     2       NA
# 2        Founding Farmers - DC  Foggy Bottom     2      423
# 3       Farmers Fishers Bakers    Georgetown     2      259
# 4          Filomena Ristorante    Georgetown     3      208

# %% [markdown]
# Awesome! We succeeded.
#
# <a id="selenium-typing"></a>
# ### Auto-typing using Selenium
#
# Now, let's explore some of the other functionality of a webdriver. We've barely scratched the surface.

# %%
# we can send keys as well
# import
from selenium.webdriver.common.keys import Keys

# %%
# open Firefox
driver = webdriver.Firefox()
# visit Python
driver.get("http://www.python.org")
# verify we're in the right place
assert "Python" in driver.title

# %% [markdown]
# Let's try automatedly typing `pycon` in the search box and hitting the return key:

# %%
# find the search position
elem = driver.find_element_by_name("q")

# clear it
elem.clear()

# type in pycon
elem.send_keys("pycon")

# send those keys
elem.send_keys(Keys.RETURN)

# %%
# close
driver.close()

# %%
# all at once:
driver = webdriver.Firefox()
driver.get("http://www.python.org")
assert "Python" in driver.title

elem = driver.find_element_by_name("q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
#assert "No results found." not in driver.page_source
driver.close()

# %% [markdown]
# The above example (and many others) are available in the Selenium docs: http://selenium-python.readthedocs.io/getting-started.html
#
# What is especially important is exploring functionality like locating elements: http://selenium-python.readthedocs.io/locating-elements.html#locating-elements
#
# FAQ:
# http://selenium-python.readthedocs.io/faq.html

# %% [markdown]
# ### Summary
#
# In this lesson, we used the Beautiful Soup library to locate elements on a website then scrape their text. We also used the Selenium headless browser to run JavaScript first before retrieving the page contents.
