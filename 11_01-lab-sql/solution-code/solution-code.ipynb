# %% [markdown]
# ## Week 11, Lab 1: SQL Practice
#
# > Author: Matt Brems

# %% [markdown]
# In this lab, you're going to have ten prompts. Each prompt will require you to do two things:
# 1. Write a SQL query.
# 2. Use the result of that query to answer the question.
#
# The purpose of this lab is to get you to practice your SQL - an **important** skill in data science! While it is possible to get these answers using Pandas, it should be your goal to do everything only in SQL.
#
# **Data**: The data used in this lab is the famous (but fake) Northwind database. It contains various tables of transactions. The schema for the Northwind database can be found [here](http://www.zentut.com/wp-content/uploads/downloads/2013/06/Northwind-Sample-Database-Diagram.pdf).

# %%
# Import Pandas and Create_Engine

import pandas as pd
from sqlalchemy import create_engine

# Set up the engine to access the data.
engine = create_engine('postgres://postgres:iloveindia@localhost:5432/northwind')

# %% [markdown]
# ### Prompt 1
#
# How many rows are there in the `customers` table of the Northwind database?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT COUNT(*) 
FROM customers;
"""

pd.read_sql_query(sql, engine)
# Out:
#    count
# 0     91

# %% [markdown]
# **Prompt 1 Answer**: 91

# %% [markdown]
# ### Prompt 2
#
# If you sort the customers in alphabetical order by name, which customer is fourth?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT * 
FROM customers
ORDER BY customers."ContactName";
"""

pd.read_sql_query(sql, engine)
# Out:
#    CustomerID                           CompanyName              ContactName  \
# 0       ROMEY                      Romero y tomillo         Alejandra Camino
# 1       MORGK                Morgenstern Gesundkost          Alexander Feuer
# 2       ANATR    Ana Trujillo Emparedados y helados             Ana Trujillo
# 3       TRADH                Tradição Hipermercados        Anabela Domingues
# 4       GOURL                   Gourmet Lanchonetes            André Fonseca
# 5       EASTC                    Eastern Connection                Ann Devon
# 6       LAMAI                      La maison d'Asie           Annette Roulet
# 7       ANTON               Antonio Moreno Taquería           Antonio Moreno
# 8       FAMIA                    Familia Arquibaldo                Aria Cruz
# 9       SPLIR                 Split Rail Beer & Ale       Art Braunschweiger
# 10      QUEDE                           Que Delícia         Bernardo Batista
# 11      FRANR                   France restauration           Carine Schmitt
# 12      LILAS                     LILA-Supermercado          Carlos González
# 13      HILAA                      HILARION-Abastos         Carlos Hernández
# 14      MAISD                          Maison Dewey          Catherine Dewey
# 15      BERGS                    Berglunds snabbköp       Christina Berglund
# 16      LACOR                  La corne d'abondance            Daniel Tonini
# 17      FISSA  FISSA Fabrica Inter. Salchichas S.A.               Diego Roel
# 18      SPECD                  Spécialités du monde        Dominique Perrier
# 19      GALED                Galería del gastrónomo         Eduardo Saavedra
# 20      CONSH                 Consolidated Holdings          Elizabeth Brown
# 21      BOTTM                 Bottom-Dollar Markets        Elizabeth Lincoln
# 22      LINOD                      LINO-Delicateses         Felipe Izquierdo
# 23      LONEP              Lonesome Pine Restaurant              Fran Wilson
# 24      CENTC            Centro comercial Moctezuma          Francisco Chang
# 25      BLONP              Blondesddsl père et fils       Frédérique Citeaux
# 26      PICCO                      Piccolo und mehr              Georg Pipps
# 27      MAGAA          Magazzini Alimentari Riuniti         Giovanni Rovelli
# 28      PERIC             Pericles Comidas clásicas      Guillermo Fernández
# 29      BLAUS               Blauer See Delikatessen               Hanna Moos
# ..        ...                                   ...                      ...
# 61      WILMK                           Wilman Kala          Matti Karttunen
# 62      REGGC                    Reggiani Caseifici          Maurizio Moroni
# 63      RICSU                    Richter Supermarkt             Michael Holz
# 64      TORTU                   Tortuga Restaurante     Miguel Angel Paolino
# 65      VAFFE                          Vaffeljernet              Palle Ibsen
# 66      FRANS                        Franchi S.p.A.            Paolo Accorti
# 67      SUPRD                      Suprêmes délices         Pascale Cartrain
# 68      HUNGO          Hungry Owl All-Night Grocers         Patricia McKenna
# 69      CACTU            Cactus Comidas para llevar         Patricio Simpson
# 70      VINET             Vins et alcools Chevalier             Paul Henriot
# 71      WELLI                Wellington Importadora            Paula Parente
# 72      RATTC            Rattlesnake Canyon Grocery             Paula Wilson
# 73      COMMI                      Comércio Mineiro             Pedro Afonso
# 74      FRANK                        Frankenversand            Peter Franken
# 75      KOENE                       Königlich Essen            Philip Cramer
# 76      WARTH                        Wartian Herkku         Pirkko Koskitalo
# 77      LEHMS                   Lehmanns Marktstand           Renate Messner
# 78      OLDWO                Old World Delicatessen            Rene Phillips
# 79      WANDK                     Die Wandernde Kuh              Rita Müller
# 80      ERNSH                          Ernst Handel            Roland Mendel
# 81      RANCH                         Rancho grande         Sergio Gutiérrez
# 82      NORTS                           North/South           Simon Crowther
# 83      DRACD              Drachenblut Delikatessen             Sven Ottlieb
# 84      AROUT                       Around the Horn             Thomas Hardy
# 85      BSBEV                         B's Beverages        Victoria Ashworth
# 86      CHOPS                     Chop-suey Chinese                Yang Wang
# 87      HUNGC            Hungry Coyote Import Store            Yoshi Latimer
# 88      LAUGB         Laughing Bacchus Wine Cellars          Yoshi Tannamuri
# 89      OCEAN                Océano Atlántico Ltda.           Yvonne Moncada
# 90      WOLZA                        Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#                       ContactTitle  \
# 0               Accounting Manager
# 1              Marketing Assistant
# 2                            Owner
# 3             Sales Representative
# 4                  Sales Associate
# 5                      Sales Agent
# 6                    Sales Manager
# 7                            Owner
# 8              Marketing Assistant
# 9                    Sales Manager
# 10              Accounting Manager
# 11               Marketing Manager
# 12              Accounting Manager
# 13            Sales Representative
# 14                     Sales Agent
# 15             Order Administrator
# 16            Sales Representative
# 17              Accounting Manager
# 18               Marketing Manager
# 19               Marketing Manager
# 20            Sales Representative
# 21              Accounting Manager
# 22                           Owner
# 23                   Sales Manager
# 24               Marketing Manager
# 25               Marketing Manager
# 26                   Sales Manager
# 27               Marketing Manager
# 28            Sales Representative
# 29            Sales Representative
# ..                             ...
# 61       Owner/Marketing Assistant
# 62                 Sales Associate
# 63                   Sales Manager
# 64                           Owner
# 65                   Sales Manager
# 66            Sales Representative
# 67              Accounting Manager
# 68                 Sales Associate
# 69                     Sales Agent
# 70              Accounting Manager
# 71                   Sales Manager
# 72  Assistant Sales Representative
# 73                 Sales Associate
# 74               Marketing Manager
# 75                 Sales Associate
# 76              Accounting Manager
# 77            Sales Representative
# 78            Sales Representative
# 79            Sales Representative
# 80                   Sales Manager
# 81            Sales Representative
# 82                 Sales Associate
# 83             Order Administrator
# 84            Sales Representative
# 85            Sales Representative
# 86                           Owner
# 87            Sales Representative
# 88             Marketing Assistant
# 89                     Sales Agent
# 90                           Owner
#
#                                            Address             City  \
# 0                                      Gran Vía, 1           Madrid
# 1                                      Heerstr. 22          Leipzig
# 2                    Avda. de la Constitución 2222      México D.F.
# 3                          Av. Inês de Castro, 414        Sao Paulo
# 4                                  Av. Brasil, 442         Campinas
# 5                                   35 King George           London
# 6                            1 rue Alsace-Lorraine         Toulouse
# 7                                  Mataderos  2312      México D.F.
# 8                                     Rua Orós, 92        Sao Paulo
# 9                                     P.O. Box 555           Lander
# 10                         Rua da Panificadora, 12   Rio de Janeiro
# 11                                  54, rue Royale           Nantes
# 12  Carrera 52 con Ave. Bolívar #65-98 Llano Largo     Barquisimeto
# 13      Carrera 22 con Ave. Carlos Soublette #8-35    San Cristóbal
# 14                             Rue Joseph-Bens 532        Bruxelles
# 15                                 Berguvsvägen  8            Luleå
# 16                          67, avenue de l'Europe       Versailles
# 17                              C/ Moralzarzal, 86           Madrid
# 18                               25, rue Lauriston            Paris
# 19                          Rambla de Cataluña, 23        Barcelona
# 20                    Berkeley Gardens 12  Brewery           London
# 21                              23 Tsawassen Blvd.        Tsawassen
# 22                         Ave. 5 de Mayo Porlamar  I. de Margarita
# 23                              89 Chiaroscuro Rd.         Portland
# 24                         Sierras de Granada 9993      México D.F.
# 25                                24, place Kléber       Strasbourg
# 26                                     Geislweg 14         Salzburg
# 27                         Via Ludovico il Moro 22          Bergamo
# 28                        Calle Dr. Jorge Cash 321      México D.F.
# 29                                  Forsterstr. 57         Mannheim
# ..                                             ...              ...
# 61                                   Keskuskatu 45         Helsinki
# 62                          Strada Provinciale 124    Reggio Emilia
# 63                               Grenzacherweg 237           Genève
# 64                                Avda. Azteca 123      México D.F.
# 65                                   Smagsloget 45            Århus
# 66                             Via Monte Bianco 34           Torino
# 67                            Boulevard Tirou, 255        Charleroi
# 68                                8 Johnstown Road             Cork
# 69                                     Cerrito 333     Buenos Aires
# 70                              59 rue de l'Abbaye            Reims
# 71                              Rua do Mercado, 12          Resende
# 72                                 2817 Milton Dr.      Albuquerque
# 73                            Av. dos Lusíadas, 23        Sao Paulo
# 74                               Berliner Platz 43          München
# 75                                   Maubelstr. 90      Brandenburg
# 76                                     Torikatu 38             Oulu
# 77                                    Magazinweg 7   Frankfurt a.M.
# 78                                 2743 Bering St.        Anchorage
# 79                               Adenauerallee 900        Stuttgart
# 80                                    Kirchgasse 6             Graz
# 81                          Av. del Libertador 900     Buenos Aires
# 82                    South House 300 Queensbridge           London
# 83                                    Walserweg 21           Aachen
# 84                                 120 Hanover Sq.           London
# 85                               Fauntleroy Circus           London
# 86                                    Hauptstr. 29             Bern
# 87                  City Center Plaza 516 Main St.            Elgin
# 88                                    1900 Oak St.        Vancouver
# 89             Ing. Gustavo Moncada 8585 Piso 20-A     Buenos Aires
# 90                                 ul. Filtrowa 68         Warszawa
#
#            Region PostalCode      Country              Phone  \
# 0            None      28001        Spain      (91) 745 6200
# 1            None      04179      Germany        0342-023176
# 2            None      05021       Mexico       (5) 555-4729
# 3              SP  05634-030       Brazil      (11) 555-2167
# 4              SP  04876-786       Brazil      (11) 555-9482
# 5            None    WX3 6FW           UK     (171) 555-0297
# 6            None      31000       France        61.77.61.10
# 7            None      05023       Mexico       (5) 555-3932
# 8              SP  05442-030       Brazil      (11) 555-9857
# 9              WY      82520          USA     (307) 555-4680
# 10             RJ  02389-673       Brazil      (21) 555-4252
# 11           None      44000       France        40.32.21.21
# 12           Lara       3508    Venezuela       (9) 331-6954
# 13        Táchira       5022    Venezuela       (5) 555-1340
# 14           None     B-1180      Belgium     (02) 201 24 67
# 15           None   S-958 22       Sweden      0921-12 34 65
# 16           None      78000       France        30.59.84.10
# 17           None      28034        Spain     (91) 555 94 44
# 18           None      75016       France    (1) 47.55.60.10
# 19           None      08022        Spain      (93) 203 4560
# 20           None    WX1 6LT           UK     (171) 555-2282
# 21             BC    T2F 8M4       Canada     (604) 555-4729
# 22  Nueva Esparta       4980    Venezuela       (8) 34-56-12
# 23             OR      97219          USA     (503) 555-9573
# 24           None      05022       Mexico       (5) 555-3392
# 25           None      67000       France        88.60.15.31
# 26           None       5020      Austria          6562-9722
# 27           None      24100        Italy         035-640230
# 28           None      05033       Mexico       (5) 552-3745
# 29           None      68306      Germany         0621-08460
# ..            ...        ...          ...                ...
# 61           None      21240      Finland        90-224 8858
# 62           None      42100        Italy        0522-556721
# 63           None       1203  Switzerland        0897-034214
# 64           None      05033       Mexico       (5) 555-2933
# 65           None       8200      Denmark        86 21 32 43
# 66           None      10100        Italy        011-4988260
# 67           None     B-6000      Belgium  (071) 23 67 22 20
# 68       Co. Cork       None      Ireland           2967 542
# 69           None       1010    Argentina       (1) 135-5555
# 70           None      51100       France        26.47.15.10
# 71             SP  08737-363       Brazil      (14) 555-8122
# 72             NM      87110          USA     (505) 555-5939
# 73             SP  05432-043       Brazil      (11) 555-7647
# 74           None      80805      Germany        089-0877310
# 75           None      14776      Germany         0555-09876
# 76           None      90110      Finland         981-443655
# 77           None      60528      Germany        069-0245984
# 78             AK      99508          USA     (907) 555-7584
# 79           None      70563      Germany        0711-020361
# 80           None       8010      Austria          7675-3425
# 81           None       1010    Argentina       (1) 123-5555
# 82           None    SW7 1RZ           UK     (171) 555-7733
# 83           None      52066      Germany        0241-039123
# 84           None    WA1 1DP           UK     (171) 555-7788
# 85           None    EC2 5NT           UK     (171) 555-1212
# 86           None       3012  Switzerland        0452-076545
# 87             OR      97827          USA     (503) 555-6874
# 88             BC    V3F 2K1       Canada     (604) 555-3392
# 89           None       1010    Argentina       (1) 135-5333
# 90           None     01-012       Poland      (26) 642-7012
#
#                   Fax
# 0       (91) 745 6210
# 1                None
# 2        (5) 555-3745
# 3       (11) 555-2168
# 4                None
# 5      (171) 555-3373
# 6         61.77.61.11
# 7                None
# 8                None
# 9      (307) 555-6525
# 10      (21) 555-4545
# 11        40.32.21.20
# 12       (9) 331-7256
# 13       (5) 555-1948
# 14     (02) 201 24 68
# 15      0921-12 34 67
# 16        30.59.85.11
# 17     (91) 555 55 93
# 18    (1) 47.55.60.20
# 19      (93) 203 4561
# 20     (171) 555-9199
# 21     (604) 555-3745
# 22       (8) 34-93-93
# 23     (503) 555-9646
# 24       (5) 555-7293
# 25        88.60.15.32
# 26          6562-9723
# 27         035-640231
# 28       (5) 545-3745
# 29         0621-08924
# ..                ...
# 61        90-224 8858
# 62        0522-556722
# 63               None
# 64               None
# 65        86 22 33 44
# 66        011-4988261
# 67  (071) 23 67 22 21
# 68          2967 3333
# 69       (1) 135-4892
# 70        26.47.15.11
# 71               None
# 72     (505) 555-3620
# 73               None
# 74        089-0877451
# 75               None
# 76         981-443655
# 77        069-0245874
# 78     (907) 555-2880
# 79        0711-035428
# 80          7675-3426
# 81       (1) 123-5556
# 82     (171) 555-2530
# 83        0241-059428
# 84     (171) 555-6750
# 85               None
# 86               None
# 87     (503) 555-2376
# 88     (604) 555-7293
# 89       (1) 135-5535
# 90      (26) 642-7012
#
# [91 rows x 11 columns]

# %% [markdown]
# **Prompt 2 Answer**: Ana Trujillo.

# %% [markdown]
# ### Prompt 3
#
# Among those customers who live in Germany, if you sort the customers in alphabetical order by name, which customer is fourth?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT * 
FROM customers
WHERE customers."Country" = 'Germany'
ORDER BY customers."ContactName";
"""

pd.read_sql_query(sql, engine)
# Out:
#    CustomerID               CompanyName          ContactName  \
# 0       MORGK    Morgenstern Gesundkost      Alexander Feuer
# 1       BLAUS   Blauer See Delikatessen           Hanna Moos
# 2       OTTIK        Ottilies Käseladen  Henriette Pfalzheim
# 3       QUICK                QUICK-Stop          Horst Kloss
# 4       TOMSP        Toms Spezialitäten        Karin Josephs
# 5       ALFKI       Alfreds Futterkiste         Maria Anders
# 6       FRANK            Frankenversand        Peter Franken
# 7       KOENE           Königlich Essen        Philip Cramer
# 8       LEHMS       Lehmanns Marktstand       Renate Messner
# 9       WANDK         Die Wandernde Kuh          Rita Müller
# 10      DRACD  Drachenblut Delikatessen         Sven Ottlieb
#
#             ContactTitle             Address            City Region  \
# 0    Marketing Assistant         Heerstr. 22         Leipzig   None
# 1   Sales Representative      Forsterstr. 57        Mannheim   None
# 2                  Owner  Mehrheimerstr. 369            Köln   None
# 3     Accounting Manager    Taucherstraße 10       Cunewalde   None
# 4      Marketing Manager       Luisenstr. 48         Münster   None
# 5   Sales Representative       Obere Str. 57          Berlin   None
# 6      Marketing Manager   Berliner Platz 43         München   None
# 7        Sales Associate       Maubelstr. 90     Brandenburg   None
# 8   Sales Representative        Magazinweg 7  Frankfurt a.M.   None
# 9   Sales Representative   Adenauerallee 900       Stuttgart   None
# 10   Order Administrator        Walserweg 21          Aachen   None
#
#    PostalCode  Country         Phone           Fax
# 0       04179  Germany   0342-023176          None
# 1       68306  Germany    0621-08460    0621-08924
# 2       50739  Germany  0221-0644327  0221-0765721
# 3       01307  Germany   0372-035188          None
# 4       44087  Germany   0251-031259   0251-035695
# 5       12209  Germany   030-0074321   030-0076545
# 6       80805  Germany   089-0877310   089-0877451
# 7       14776  Germany    0555-09876          None
# 8       60528  Germany   069-0245984   069-0245874
# 9       70563  Germany   0711-020361   0711-035428
# 10      52066  Germany   0241-039123   0241-059428

# %% [markdown]
# **Prompt 3 Answer**: Horst Kloss.

# %% [markdown]
# ### Prompt 4
#
# From the `employees` table, what are the first names of the individuals who have a birthdate in the 1960s?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT employees."FirstName"
FROM employees
WHERE employees."BirthDate" BETWEEN '1-1-1960' AND '12-31-1969';
"""

pd.read_sql_query(sql, engine)
# Out:
#   FirstName
# 0     Janet
# 1   Michael
# 2    Robert
# 3      Anne

# %% [markdown]
# **Prompt 4 Answer**: There are four employees born in the 1960s: Janet, Michael, Robert, and Anne.

# %% [markdown]
# ### Prompt 5
#
# In `order_details` table of the Northwind database, what is the total number of units sold for products 2, 3, and 4?
# > You should give us three numbers - one for each `ProductID`.

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT order_details."ProductID", SUM(order_details."Quantity") 
FROM order_details
WHERE order_details."ProductID" BETWEEN 2 AND 4
GROUP BY order_details."ProductID"
ORDER BY order_details."ProductID";
"""

pd.read_sql_query(sql, engine)
# Out:
#    ProductID   sum
# 0          2  1057
# 1          3   328
# 2          4   453

# %% [markdown]
# **Prompt 5 Answer**:
# - 1,057 units of ProductID 2 have been sold,
# - 328 units of ProductID 3 have been sold, and
# - 453 units of ProductID 4 have been sold.

# %% [markdown]
# ### Prompt 6
#
# From the `order_details` table of the Northwind database, calculate the revenue per product. In your SQL output, rename the revenue column `Revenue` and sort your results from largest revenue per product to smallest revenue per product. Which `ProductID` has the fifth-highest revenue, and what is that revenue rounded to the nearest dollar?
# > Note that revenue for a given product should be equal to the total unit price of that product times the quantity. You do not need to worry about the discount here. If you haven't multiplied columns together before, [this StackOverflow question](https://stackoverflow.com/questions/7536996/multiplying-two-columns-in-sql-server/7537059) may be helpful.

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT order_details."ProductID", SUM(order_details."Quantity" * order_details."UnitPrice") AS "Revenue"
FROM order_details
GROUP BY order_details."ProductID"
ORDER BY "Revenue" DESC
LIMIT 5;
"""

pd.read_sql_query(sql, engine)
# Out:
#    ProductID        Revenue
# 0         38  149984.200821
# 1         29   87736.400513
# 2         59   76296.000000
# 3         60   50286.000374
# 4         62   49827.899998

# %% [markdown]
# **Prompt 6 Answer**: ProductID 62 has the fifth-highest revenue, at \$49,828.

# %% [markdown]
# ### Prompt 7
#
# From the `products` table of the Northwind database, show the `ProductName`, `UnitsInStock`, and `UnitsOnOrder` values for those products who have more units on order than units in stock. Among these results, which product has the most units on order?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT products."ProductName", products."UnitsInStock", products."UnitsOnOrder"
FROM products
WHERE products."UnitsInStock" < products."UnitsOnOrder";
"""

pd.read_sql_query(sql, engine)
# Out:
#                   ProductName  UnitsInStock  UnitsOnOrder
# 0                       Chang            17            40
# 1               Aniseed Syrup            13            70
# 2              Queso Cabrales            22            30
# 3         Sir Rodney's Scones             3            40
# 4           Gorgonzola Telino             0            70
# 5          Mascarpone Fabioli             9            40
# 6                  Gravad lax            11            50
# 7                 Rogede sild             5            70
# 8                   Chocolade            15            70
# 9                    Maxilaku            10            60
# 10  Wimmers gute Semmelknödel            22            80
# 11  Louisiana Hot Spiced Okra             4           100
# 12        Scottish Longbreads             6            10
# 13              Longlife Tofu             4            20

# %% [markdown]
# **Prompt 7 Answer**: Louisiana Hot Spiced Okra has the most units on order, with 100.

# %% [markdown]
# ### Prompt 8
#
# From the `order_details` table, show the products that have an average discount of at least 8%. Among these results, which average discount is closest to 8%?

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT order_details."ProductID", AVG(order_details."Discount")
FROM order_details
GROUP BY order_details."ProductID"
HAVING AVG(order_details."Discount") >= 0.08
ORDER BY AVG(order_details."Discount") DESC;
"""

pd.read_sql_query(sql, engine)
# Out:
#    ProductID       avg
# 0         48  0.108333
# 1          2  0.102273
# 2          9  0.100000
# 3         58  0.100000
# 4         25  0.086111
# 5         30  0.081250

# %% [markdown]
# **Prompt 8 Answer**: Among all ProductIDs with an average discount of at least 8%, ProductID 30 has an average discount closest to 8% with an average discount of 8.125%.

# %% [markdown]
# ### Prompt 9
#
# Return the `orders` table, but also include the first name, last name, and country of the employee assigned to each order. What is the first and last name of the employee assigned to `OrderID` 11077? (This is the last row in the data, provided that you do not sort.)

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT orders.*, employees."FirstName", employees."LastName", employees."Country"
FROM orders
LEFT JOIN employees
ON orders."EmployeeID" = employees."EmployeeID";
"""

pd.read_sql_query(sql, engine)
# Out:
#      OrderID CustomerID  EmployeeID   OrderDate RequiredDate ShippedDate  \
# 0      10248      VINET           5  1996-07-04   1996-08-01  1996-07-16
# 1      10249      TOMSP           6  1996-07-05   1996-08-16  1996-07-10
# 2      10250      HANAR           4  1996-07-08   1996-08-05  1996-07-12
# 3      10251      VICTE           3  1996-07-08   1996-08-05  1996-07-15
# 4      10252      SUPRD           4  1996-07-09   1996-08-06  1996-07-11
# 5      10253      HANAR           3  1996-07-10   1996-07-24  1996-07-16
# 6      10254      CHOPS           5  1996-07-11   1996-08-08  1996-07-23
# 7      10255      RICSU           9  1996-07-12   1996-08-09  1996-07-15
# 8      10256      WELLI           3  1996-07-15   1996-08-12  1996-07-17
# 9      10257      HILAA           4  1996-07-16   1996-08-13  1996-07-22
# 10     10258      ERNSH           1  1996-07-17   1996-08-14  1996-07-23
# 11     10259      CENTC           4  1996-07-18   1996-08-15  1996-07-25
# 12     10260      OTTIK           4  1996-07-19   1996-08-16  1996-07-29
# 13     10261      QUEDE           4  1996-07-19   1996-08-16  1996-07-30
# 14     10262      RATTC           8  1996-07-22   1996-08-19  1996-07-25
# 15     10263      ERNSH           9  1996-07-23   1996-08-20  1996-07-31
# 16     10264      FOLKO           6  1996-07-24   1996-08-21  1996-08-23
# 17     10265      BLONP           2  1996-07-25   1996-08-22  1996-08-12
# 18     10266      WARTH           3  1996-07-26   1996-09-06  1996-07-31
# 19     10267      FRANK           4  1996-07-29   1996-08-26  1996-08-06
# 20     10268      GROSR           8  1996-07-30   1996-08-27  1996-08-02
# 21     10269      WHITC           5  1996-07-31   1996-08-14  1996-08-09
# 22     10270      WARTH           1  1996-08-01   1996-08-29  1996-08-02
# 23     10271      SPLIR           6  1996-08-01   1996-08-29  1996-08-30
# 24     10272      RATTC           6  1996-08-02   1996-08-30  1996-08-06
# 25     10273      QUICK           3  1996-08-05   1996-09-02  1996-08-12
# 26     10274      VINET           6  1996-08-06   1996-09-03  1996-08-16
# 27     10275      MAGAA           1  1996-08-07   1996-09-04  1996-08-09
# 28     10276      TORTU           8  1996-08-08   1996-08-22  1996-08-14
# 29     10277      MORGK           2  1996-08-09   1996-09-06  1996-08-13
# ..       ...        ...         ...         ...          ...         ...
# 800    11048      BOTTM           7  1998-04-24   1998-05-22  1998-04-30
# 801    11049      GOURL           3  1998-04-24   1998-05-22  1998-05-04
# 802    11050      FOLKO           8  1998-04-27   1998-05-25  1998-05-05
# 803    11051      LAMAI           7  1998-04-27   1998-05-25        None
# 804    11052      HANAR           3  1998-04-27   1998-05-25  1998-05-01
# 805    11053      PICCO           2  1998-04-27   1998-05-25  1998-04-29
# 806    11054      CACTU           8  1998-04-28   1998-05-26        None
# 807    11055      HILAA           7  1998-04-28   1998-05-26  1998-05-05
# 808    11056      EASTC           8  1998-04-28   1998-05-12  1998-05-01
# 809    11057      NORTS           3  1998-04-29   1998-05-27  1998-05-01
# 810    11058      BLAUS           9  1998-04-29   1998-05-27        None
# 811    11059      RICAR           2  1998-04-29   1998-06-10        None
# 812    11060      FRANS           2  1998-04-30   1998-05-28  1998-05-04
# 813    11061      GREAL           4  1998-04-30   1998-06-11        None
# 814    11062      REGGC           4  1998-04-30   1998-05-28        None
# 815    11063      HUNGO           3  1998-04-30   1998-05-28  1998-05-06
# 816    11064      SAVEA           1  1998-05-01   1998-05-29  1998-05-04
# 817    11065      LILAS           8  1998-05-01   1998-05-29        None
# 818    11066      WHITC           7  1998-05-01   1998-05-29  1998-05-04
# 819    11067      DRACD           1  1998-05-04   1998-05-18  1998-05-06
# 820    11068      QUEEN           8  1998-05-04   1998-06-01        None
# 821    11069      TORTU           1  1998-05-04   1998-06-01  1998-05-06
# 822    11070      LEHMS           2  1998-05-05   1998-06-02        None
# 823    11071      LILAS           1  1998-05-05   1998-06-02        None
# 824    11072      ERNSH           4  1998-05-05   1998-06-02        None
# 825    11073      PERIC           2  1998-05-05   1998-06-02        None
# 826    11074      SIMOB           7  1998-05-06   1998-06-03        None
# 827    11075      RICSU           8  1998-05-06   1998-06-03        None
# 828    11076      BONAP           4  1998-05-06   1998-06-03        None
# 829    11077      RATTC           1  1998-05-06   1998-06-03        None
#
#      ShipVia  Freight                      ShipName  \
# 0          3    32.38     Vins et alcools Chevalier
# 1          1    11.61            Toms Spezialitäten
# 2          2    65.83                 Hanari Carnes
# 3          1    41.34          Victuailles en stock
# 4          2    51.30              Suprêmes délices
# 5          2    58.17                 Hanari Carnes
# 6          2    22.98             Chop-suey Chinese
# 7          3   148.33            Richter Supermarkt
# 8          2    13.97        Wellington Importadora
# 9          3    81.91              HILARION-Abastos
# 10         1   140.51                  Ernst Handel
# 11         3     3.25    Centro comercial Moctezuma
# 12         1    55.09            Ottilies Käseladen
# 13         2     3.05                   Que Delícia
# 14         3    48.29    Rattlesnake Canyon Grocery
# 15         3   146.06                  Ernst Handel
# 16         3     3.67                Folk och fä HB
# 17         1    55.28          Blondel père et fils
# 18         3    25.73                Wartian Herkku
# 19         1   208.58                Frankenversand
# 20         3    66.29          GROSELLA-Restaurante
# 21         1     4.56          White Clover Markets
# 22         1   136.54                Wartian Herkku
# 23         2     4.54         Split Rail Beer & Ale
# 24         2    98.03    Rattlesnake Canyon Grocery
# 25         3    76.07                    QUICK-Stop
# 26         1     6.01     Vins et alcools Chevalier
# 27         1    26.93  Magazzini Alimentari Riuniti
# 28         3    13.84           Tortuga Restaurante
# 29         3   125.77        Morgenstern Gesundkost
# ..       ...      ...                           ...
# 800        3    24.12         Bottom-Dollar Markets
# 801        1     8.34           Gourmet Lanchonetes
# 802        2    59.41                Folk och fä HB
# 803        3     2.79              La maison d'Asie
# 804        1    67.26                 Hanari Carnes
# 805        2    53.05              Piccolo und mehr
# 806        1     0.33    Cactus Comidas para llevar
# 807        2   120.92              HILARION-Abastos
# 808        2   278.96            Eastern Connection
# 809        3     4.13                   North/South
# 810        3    31.14       Blauer See Delikatessen
# 811        2    85.80            Ricardo Adocicados
# 812        2    10.98                Franchi S.p.A.
# 813        3    14.01       Great Lakes Food Market
# 814        2    29.93            Reggiani Caseifici
# 815        2    81.73  Hungry Owl All-Night Grocers
# 816        1    30.09            Save-a-lot Markets
# 817        1    12.91             LILA-Supermercado
# 818        2    44.72          White Clover Markets
# 819        2     7.98      Drachenblut Delikatessen
# 820        2    81.75                 Queen Cozinha
# 821        2    15.67           Tortuga Restaurante
# 822        1   136.00           Lehmanns Marktstand
# 823        1     0.93             LILA-Supermercado
# 824        2   258.64                  Ernst Handel
# 825        2    24.95     Pericles Comidas clásicas
# 826        2    18.44                 Simons bistro
# 827        2     6.19            Richter Supermarkt
# 828        2    38.28                      Bon app'
# 829        2     8.53    Rattlesnake Canyon Grocery
#
#                                         ShipAddress        ShipCity  \
# 0                                59 rue de l'Abbaye           Reims
# 1                                     Luisenstr. 48         Münster
# 2                                   Rua do Paço, 67  Rio de Janeiro
# 3                                2, rue du Commerce            Lyon
# 4                              Boulevard Tirou, 255       Charleroi
# 5                                   Rua do Paço, 67  Rio de Janeiro
# 6                                      Hauptstr. 31            Bern
# 7                                       Starenweg 5          Genève
# 8                                Rua do Mercado, 12         Resende
# 9        Carrera 22 con Ave. Carlos Soublette #8-35   San Cristóbal
# 10                                     Kirchgasse 6            Graz
# 11                          Sierras de Granada 9993     México D.F.
# 12                               Mehrheimerstr. 369            Köln
# 13                          Rua da Panificadora, 12  Rio de Janeiro
# 14                                  2817 Milton Dr.     Albuquerque
# 15                                     Kirchgasse 6            Graz
# 16                                     Åkergatan 24          Bräcke
# 17                                 24, place Kléber      Strasbourg
# 18                                      Torikatu 38            Oulu
# 19                                Berliner Platz 43         München
# 20                        5ª Ave. Los Palos Grandes         Caracas
# 21                              1029 - 12th Ave. S.         Seattle
# 22                                      Torikatu 38            Oulu
# 23                                     P.O. Box 555          Lander
# 24                                  2817 Milton Dr.     Albuquerque
# 25                                 Taucherstraße 10       Cunewalde
# 26                               59 rue de l'Abbaye           Reims
# 27                          Via Ludovico il Moro 22         Bergamo
# 28                                 Avda. Azteca 123     México D.F.
# 29                                      Heerstr. 22         Leipzig
# ..                                              ...             ...
# 800                              23 Tsawassen Blvd.       Tsawassen
# 801                                 Av. Brasil, 442        Campinas
# 802                                    Åkergatan 24          Bräcke
# 803                           1 rue Alsace-Lorraine        Toulouse
# 804                                 Rua do Paço, 67  Rio de Janeiro
# 805                                     Geislweg 14        Salzburg
# 806                                     Cerrito 333    Buenos Aires
# 807      Carrera 22 con Ave. Carlos Soublette #8-35   San Cristóbal
# 808                                  35 King George          London
# 809                    South House 300 Queensbridge          London
# 810                                  Forsterstr. 57        Mannheim
# 811                             Av. Copacabana, 267  Rio de Janeiro
# 812                             Via Monte Bianco 34          Torino
# 813                                2732 Baker Blvd.          Eugene
# 814                          Strada Provinciale 124   Reggio Emilia
# 815                                8 Johnstown Road            Cork
# 816                                 187 Suffolk Ln.           Boise
# 817  Carrera 52 con Ave. Bolívar #65-98 Llano Largo    Barquisimeto
# 818                             1029 - 12th Ave. S.         Seattle
# 819                                    Walserweg 21          Aachen
# 820                       Alameda dos Canàrios, 891       Sao Paulo
# 821                                Avda. Azteca 123     México D.F.
# 822                                    Magazinweg 7  Frankfurt a.M.
# 823  Carrera 52 con Ave. Bolívar #65-98 Llano Largo    Barquisimeto
# 824                                    Kirchgasse 6            Graz
# 825                        Calle Dr. Jorge Cash 321     México D.F.
# 826                                    Vinbæltet 34       Kobenhavn
# 827                                     Starenweg 5          Genève
# 828                            12, rue des Bouchers       Marseille
# 829                                 2817 Milton Dr.     Albuquerque
#
#     ShipRegion ShipPostalCode  ShipCountry FirstName   LastName Country
# 0         None          51100       France    Steven   Buchanan      UK
# 1         None          44087      Germany   Michael     Suyama      UK
# 2           RJ      05454-876       Brazil  Margaret    Peacock     USA
# 3         None          69004       France     Janet  Leverling     USA
# 4         None         B-6000      Belgium  Margaret    Peacock     USA
# 5           RJ      05454-876       Brazil     Janet  Leverling     USA
# 6         None           3012  Switzerland    Steven   Buchanan      UK
# 7         None           1204  Switzerland      Anne  Dodsworth      UK
# 8           SP      08737-363       Brazil     Janet  Leverling     USA
# 9      Táchira           5022    Venezuela  Margaret    Peacock     USA
# 10        None           8010      Austria     Nancy    Davolio     USA
# 11        None          05022       Mexico  Margaret    Peacock     USA
# 12        None          50739      Germany  Margaret    Peacock     USA
# 13          RJ      02389-673       Brazil  Margaret    Peacock     USA
# 14          NM          87110          USA     Laura   Callahan     USA
# 15        None           8010      Austria      Anne  Dodsworth      UK
# 16        None       S-844 67       Sweden   Michael     Suyama      UK
# 17        None          67000       France    Andrew     Fuller     USA
# 18        None          90110      Finland     Janet  Leverling     USA
# 19        None          80805      Germany  Margaret    Peacock     USA
# 20          DF           1081    Venezuela     Laura   Callahan     USA
# 21          WA          98124          USA    Steven   Buchanan      UK
# 22        None          90110      Finland     Nancy    Davolio     USA
# 23          WY          82520          USA   Michael     Suyama      UK
# 24          NM          87110          USA   Michael     Suyama      UK
# 25        None          01307      Germany     Janet  Leverling     USA
# 26        None          51100       France   Michael     Suyama      UK
# 27        None          24100        Italy     Nancy    Davolio     USA
# 28        None          05033       Mexico     Laura   Callahan     USA
# 29        None          04179      Germany    Andrew     Fuller     USA
# ..         ...            ...          ...       ...        ...     ...
# 800         BC        T2F 8M4       Canada    Robert       King      UK
# 801         SP      04876-786       Brazil     Janet  Leverling     USA
# 802       None       S-844 67       Sweden     Laura   Callahan     USA
# 803       None          31000       France    Robert       King      UK
# 804         RJ      05454-876       Brazil     Janet  Leverling     USA
# 805       None           5020      Austria    Andrew     Fuller     USA
# 806       None           1010    Argentina     Laura   Callahan     USA
# 807    Táchira           5022    Venezuela    Robert       King      UK
# 808       None        WX3 6FW           UK     Laura   Callahan     USA
# 809       None        SW7 1RZ           UK     Janet  Leverling     USA
# 810       None          68306      Germany      Anne  Dodsworth      UK
# 811         RJ      02389-890       Brazil    Andrew     Fuller     USA
# 812       None          10100        Italy    Andrew     Fuller     USA
# 813         OR          97403          USA  Margaret    Peacock     USA
# 814       None          42100        Italy  Margaret    Peacock     USA
# 815   Co. Cork           None      Ireland     Janet  Leverling     USA
# 816         ID          83720          USA     Nancy    Davolio     USA
# 817       Lara           3508    Venezuela     Laura   Callahan     USA
# 818         WA          98124          USA    Robert       King      UK
# 819       None          52066      Germany     Nancy    Davolio     USA
# 820         SP      05487-020       Brazil     Laura   Callahan     USA
# 821       None          05033       Mexico     Nancy    Davolio     USA
# 822       None          60528      Germany    Andrew     Fuller     USA
# 823       Lara           3508    Venezuela     Nancy    Davolio     USA
# 824       None           8010      Austria  Margaret    Peacock     USA
# 825       None          05033       Mexico    Andrew     Fuller     USA
# 826       None           1734      Denmark    Robert       King      UK
# 827       None           1204  Switzerland     Laura   Callahan     USA
# 828       None          13008       France  Margaret    Peacock     USA
# 829         NM          87110          USA     Nancy    Davolio     USA
#
# [830 rows x 17 columns]

# %% [markdown]
# **Prompt 9 Answer**: `OrderID` 11077 corresponds to Nancy Davolio.

# %% [markdown]
# ### Prompt 10
#
# Find the average amount of freight across all orders, broken out by country of *employee*. (**NOT `ShipCountry`**.) How much higher is the average freight from UK employees than the average freight from US employees?
#
# > For a bonus, round the freight to the nearest whole number and rename the column `Average Freight`.

# %%
# Use a SQL query to find the answer to the above prompt.

sql = """
SELECT employees."Country", AVG(orders."Freight") AS "Average Freight"
FROM orders
LEFT JOIN employees
ON orders."EmployeeID" = employees."EmployeeID"
GROUP BY employees."Country";
"""

pd.read_sql_query(sql, engine)
# Out:
#   Country  Average Freight
# 0      UK        78.977143
# 1     USA        77.973284

# %% [markdown]
# **Prompt 10 Answer**: The average freight for orders shipped by UK employees is about 1 unit higher than the average freight shipped by US employees.
