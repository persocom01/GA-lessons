# %% [markdown]
# # Load Dataset from `make_classification`

# %% [markdown]
# # Train/Test Split

# %% [markdown]
# # Tuning AdaBoostClassifier

# %% [markdown]
# # GradientBoostingClassifier

# %% [markdown]
# # VotingClassifier
